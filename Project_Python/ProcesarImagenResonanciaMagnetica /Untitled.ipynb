# %%
import os
import pydicom
import matplotlib.pyplot as plt
from ipywidgets import interact, IntSlider
import numpy as np

# %%
# Función para cargar todas las imágenes DICOM de un directorio
def load_dicom_images(directory):
    dicom_files = [os.path.join(directory, f) for f in os.listdir(directory) if f.endswith('.dcm')]
    dicom_files.sort()  # Asegurarse de que estén en orden
    dicom_images = [pydicom.dcmread(f) for f in dicom_files]
    return dicom_images

# Función para mostrar una imagen específica
def show_dicom_image(index, dicom_images):
    plt.figure(figsize=(8, 8))
    plt.imshow(dicom_images[index].pixel_array, cmap='gray')
    plt.title(f'Capa {index + 1}')
    plt.axis('off')
    plt.show()

# Directorio donde están tus archivos DICOM
dicom_directory = '/home/camilo/LaverGit/Data_analytic_and_science_project/ProjectData_Analytic_and_Science/Project_Python/ProcesarImagenResonanciaMagnetica /AVILAMORAROBERT'

# Cargar las imágenes DICOM
dicom_images = load_dicom_images(dicom_directory)

# Crear un slider interactivo
interact(show_dicom_image, index=IntSlider(min=0, max=len(dicom_images)-1, step=1, value=0), dicom_images=fixed(dicom_images))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 23
#      20 dicom_images = load_dicom_images(dicom_directory)
#      22 # Crear un slider interactivo
# ---> 23 interact(show_dicom_image, index=IntSlider(min=0, max=len(dicom_images)-1, step=1, value=0), dicom_images=fixed(dicom_images))
#
# NameError: name 'fixed' is not defined

# %%
import os
import pydicom
import matplotlib.pyplot as plt
from ipywidgets import interact, IntSlider, fixed  # Importar 'fixed' desde ipywidgets
import numpy as np

# Función para cargar todas las imágenes DICOM de un directorio
def load_dicom_images(directory):
    dicom_files = [os.path.join(directory, f) for f in os.listdir(directory) if f.endswith('.dcm')]
    dicom_files.sort()  # Asegurarse de que estén en orden
    dicom_images = [pydicom.dcmread(f) for f in dicom_files]
    return dicom_images

# Función para mostrar una imagen específica
def show_dicom_image(index, dicom_images):
    plt.figure(figsize=(8, 8))
    plt.imshow(dicom_images[index].pixel_array, cmap='gray')
    plt.title(f'Capa {index + 1}')
    plt.axis('off')
    plt.show()

# Directorio donde están tus archivos DICOM
#dicom_directory = 'ruta/al/directorio/dicom'  # Cambia esto a la ruta correcta

# Cargar las imágenes DICOM
dicom_images = load_dicom_images(dicom_directory)

# Crear un slider interactivo
interact(show_dicom_image, index=IntSlider(min=0, max=len(dicom_images)-1, step=1, value=0), dicom_images=fixed(dicom_images))
# Out:
# interactive(children=(IntSlider(value=0, description='index', max=107), Output()), _dom_classes=('widget-inter…
# <function __main__.show_dicom_image(index, dicom_images)>

# %%
import os
import pydicom
import matplotlib.pyplot as plt
from ipywidgets import interact, IntSlider, fixed
import numpy as np

# Función para cargar todas las imágenes DICOM de un directorio
def load_dicom_images(directory):
    dicom_files = [os.path.join(directory, f) for f in os.listdir(directory) if f.endswith('.dcm')]
    dicom_files.sort()  # Asegurarse de que estén en orden
    dicom_images = [pydicom.dcmread(f) for f in dicom_files]
    return dicom_images

# Función para mostrar una imagen específica
def show_dicom_image(index, dicom_images):
    plt.figure(figsize=(8, 8))
    plt.imshow(dicom_images[index].pixel_array, cmap='gray')
    plt.title(f'Capa {index + 1}')
    plt.axis('off')
    plt.show()

# Directorio donde están tus archivos DICOM
#dicom_directory = 'ruta/al/directorio/dicom'  # Cambia esto a la ruta correcta

# Cargar las imágenes DICOM
dicom_images = load_dicom_images(dicom_directory)

# Crear un slider interactivo
interact(
    show_dicom_image,
    index=IntSlider(min=0, max=len(dicom_images) - 1, step=1, value=0, description='Capa:'),
    dicom_images=fixed(dicom_images)
)
# Out:
# interactive(children=(IntSlider(value=0, description='Capa:', max=107), Output()), _dom_classes=('widget-inter…
# <function __main__.show_dicom_image(index, dicom_images)>
